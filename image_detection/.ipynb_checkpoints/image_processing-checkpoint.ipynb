# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\kilic\anaconda3\lib\site-packages (4.8.0.74)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\kilic\anaconda3\lib\site-packages (from opencv-python) (1.24.3)
# Requirement already satisfied: opencv-python in c:\users\kilic\anaconda3\lib\site-packages (4.8.0.74)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\kilic\anaconda3\lib\site-packages (from opencv-python) (1.24.3)

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in c:\users\kilic\anaconda3\lib\site-packages (9.4.0)
# Requirement already satisfied: Pillow in c:\users\kilic\anaconda3\lib\site-packages (9.4.0)

# %%
# !pip install -U scikit-image
# Out:
# Requirement already satisfied: scikit-image in c:\users\kilic\anaconda3\lib\site-packages (0.21.0)
# Requirement already satisfied: numpy>=1.21.1 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image) (1.24.3)
# Requirement already satisfied: scipy>=1.8 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image) (1.10.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image) (2.8.4)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image) (9.4.0)
# Requirement already satisfied: imageio>=2.27 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image) (2.31.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image) (2023.7.18)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image) (1.4.1)
# Requirement already satisfied: packaging>=21 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image) (23.0)
# Requirement already satisfied: lazy_loader>=0.2 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image) (0.2)
# Requirement already satisfied: scikit-image in c:\users\kilic\anaconda3\lib\site-packages (0.21.0)
# Requirement already satisfied: numpy>=1.21.1 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image) (1.24.3)
# Requirement already satisfied: scipy>=1.8 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image) (1.10.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image) (2.8.4)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image) (9.4.0)
# Requirement already satisfied: imageio>=2.27 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image) (2.31.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image) (2023.7.18)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image) (1.4.1)
# Requirement already satisfied: packaging>=21 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image) (23.0)
# Requirement already satisfied: lazy_loader>=0.2 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image) (0.2)

# %%
# !pip install python-resize-image
# Out:
# Requirement already satisfied: python-resize-image in c:\users\kilic\anaconda3\lib\site-packages (1.1.20)
# Requirement already satisfied: Pillow>=5.1.0 in c:\users\kilic\anaconda3\lib\site-packages (from python-resize-image) (9.4.0)
# Requirement already satisfied: requests>=2.19.1 in c:\users\kilic\anaconda3\lib\site-packages (from python-resize-image) (2.29.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kilic\anaconda3\lib\site-packages (from requests>=2.19.1->python-resize-image) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kilic\anaconda3\lib\site-packages (from requests>=2.19.1->python-resize-image) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kilic\anaconda3\lib\site-packages (from requests>=2.19.1->python-resize-image) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kilic\anaconda3\lib\site-packages (from requests>=2.19.1->python-resize-image) (2023.5.7)
# Requirement already satisfied: python-resize-image in c:\users\kilic\anaconda3\lib\site-packages (1.1.20)
# Requirement already satisfied: Pillow>=5.1.0 in c:\users\kilic\anaconda3\lib\site-packages (from python-resize-image) (9.4.0)
# Requirement already satisfied: requests>=2.19.1 in c:\users\kilic\anaconda3\lib\site-packages (from python-resize-image) (2.29.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kilic\anaconda3\lib\site-packages (from requests>=2.19.1->python-resize-image) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kilic\anaconda3\lib\site-packages (from requests>=2.19.1->python-resize-image) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kilic\anaconda3\lib\site-packages (from requests>=2.19.1->python-resize-image) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kilic\anaconda3\lib\site-packages (from requests>=2.19.1->python-resize-image) (2023.5.7)

# %%
# !pip install -U albumentations --no-binary qudida,albumentations
# Out:
# Requirement already satisfied: albumentations in c:\users\kilic\anaconda3\lib\site-packages (1.3.1)
# Requirement already satisfied: numpy>=1.11.1 in c:\users\kilic\anaconda3\lib\site-packages (from albumentations) (1.24.3)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\kilic\anaconda3\lib\site-packages (from albumentations) (1.10.1)
# Requirement already satisfied: scikit-image>=0.16.1 in c:\users\kilic\anaconda3\lib\site-packages (from albumentations) (0.21.0)
# Requirement already satisfied: PyYAML in c:\users\kilic\anaconda3\lib\site-packages (from albumentations) (6.0)
# Requirement already satisfied: qudida>=0.0.4 in c:\users\kilic\anaconda3\lib\site-packages (from albumentations) (0.0.4)
# Requirement already satisfied: opencv-python>=4.1.1 in c:\users\kilic\anaconda3\lib\site-packages (from albumentations) (4.8.0.74)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\kilic\anaconda3\lib\site-packages (from qudida>=0.0.4->albumentations) (1.2.2)
# Requirement already satisfied: typing-extensions in c:\users\kilic\anaconda3\lib\site-packages (from qudida>=0.0.4->albumentations) (4.5.0)
# Requirement already satisfied: networkx>=2.8 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->albumentations) (2.8.4)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->albumentations) (9.4.0)
# Requirement already satisfied: imageio>=2.27 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->albumentations) (2.31.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->albumentations) (2023.7.18)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->albumentations) (1.4.1)
# Requirement already satisfied: packaging>=21 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->albumentations) (23.0)
# Requirement already satisfied: lazy_loader>=0.2 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->albumentations) (0.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (2.2.0)
# Requirement already satisfied: albumentations in c:\users\kilic\anaconda3\lib\site-packages (1.3.1)
# Requirement already satisfied: numpy>=1.11.1 in c:\users\kilic\anaconda3\lib\site-packages (from albumentations) (1.24.3)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\kilic\anaconda3\lib\site-packages (from albumentations) (1.10.1)
# Requirement already satisfied: scikit-image>=0.16.1 in c:\users\kilic\anaconda3\lib\site-packages (from albumentations) (0.21.0)
# Requirement already satisfied: PyYAML in c:\users\kilic\anaconda3\lib\site-packages (from albumentations) (6.0)
# Requirement already satisfied: qudida>=0.0.4 in c:\users\kilic\anaconda3\lib\site-packages (from albumentations) (0.0.4)
# Requirement already satisfied: opencv-python>=4.1.1 in c:\users\kilic\anaconda3\lib\site-packages (from albumentations) (4.8.0.74)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\kilic\anaconda3\lib\site-packages (from qudida>=0.0.4->albumentations) (1.2.2)
# Requirement already satisfied: typing-extensions in c:\users\kilic\anaconda3\lib\site-packages (from qudida>=0.0.4->albumentations) (4.5.0)
# Requirement already satisfied: networkx>=2.8 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->albumentations) (2.8.4)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->albumentations) (9.4.0)
# Requirement already satisfied: imageio>=2.27 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->albumentations) (2.31.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->albumentations) (2023.7.18)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->albumentations) (1.4.1)
# Requirement already satisfied: packaging>=21 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->albumentations) (23.0)
# Requirement already satisfied: lazy_loader>=0.2 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->albumentations) (0.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (2.2.0)

# %%
# !pip install python-math
# Out:
# Requirement already satisfied: python-math in c:\users\kilic\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: python-math in c:\users\kilic\anaconda3\lib\site-packages (0.0.1)

# %%
# !pip install image-processing
# Out:
# Requirement already satisfied: image-processing in c:\users\kilic\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: scikit-image>=0.16.1 in c:\users\kilic\anaconda3\lib\site-packages (from image-processing) (0.21.0)
# Requirement already satisfied: numpy in c:\users\kilic\anaconda3\lib\site-packages (from image-processing) (1.24.3)
# Requirement already satisfied: matplotlib in c:\users\kilic\anaconda3\lib\site-packages (from image-processing) (3.7.1)
# Requirement already satisfied: scipy>=1.8 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->image-processing) (1.10.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->image-processing) (2.8.4)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->image-processing) (9.4.0)
# Requirement already satisfied: imageio>=2.27 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->image-processing) (2.31.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->image-processing) (2023.7.18)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->image-processing) (1.4.1)
# Requirement already satisfied: packaging>=21 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->image-processing) (23.0)
# Requirement already satisfied: lazy_loader>=0.2 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->image-processing) (0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kilic\anaconda3\lib\site-packages (from matplotlib->image-processing) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\kilic\anaconda3\lib\site-packages (from matplotlib->image-processing) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kilic\anaconda3\lib\site-packages (from matplotlib->image-processing) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kilic\anaconda3\lib\site-packages (from matplotlib->image-processing) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kilic\anaconda3\lib\site-packages (from matplotlib->image-processing) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kilic\anaconda3\lib\site-packages (from matplotlib->image-processing) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\kilic\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->image-processing) (1.16.0)
# Requirement already satisfied: image-processing in c:\users\kilic\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: scikit-image>=0.16.1 in c:\users\kilic\anaconda3\lib\site-packages (from image-processing) (0.21.0)
# Requirement already satisfied: numpy in c:\users\kilic\anaconda3\lib\site-packages (from image-processing) (1.24.3)
# Requirement already satisfied: matplotlib in c:\users\kilic\anaconda3\lib\site-packages (from image-processing) (3.7.1)
# Requirement already satisfied: scipy>=1.8 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->image-processing) (1.10.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->image-processing) (2.8.4)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->image-processing) (9.4.0)
# Requirement already satisfied: imageio>=2.27 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->image-processing) (2.31.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->image-processing) (2023.7.18)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->image-processing) (1.4.1)
# Requirement already satisfied: packaging>=21 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->image-processing) (23.0)
# Requirement already satisfied: lazy_loader>=0.2 in c:\users\kilic\anaconda3\lib\site-packages (from scikit-image>=0.16.1->image-processing) (0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kilic\anaconda3\lib\site-packages (from matplotlib->image-processing) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\kilic\anaconda3\lib\site-packages (from matplotlib->image-processing) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kilic\anaconda3\lib\site-packages (from matplotlib->image-processing) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kilic\anaconda3\lib\site-packages (from matplotlib->image-processing) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kilic\anaconda3\lib\site-packages (from matplotlib->image-processing) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kilic\anaconda3\lib\site-packages (from matplotlib->image-processing) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\kilic\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->image-processing) (1.16.0)

# %%
import cv2
import numpy
import pandas
from PIL import Image
from skimage import data, io, filters
from resizeimage import resizeimage
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import skimage
from PIL.ExifTags import TAGS
# Out:
# C:\Users\kilic\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
# C:\Users\kilic\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
config_file = 'ssd_mobilenet_v3_large_coco_2020_01_14.pbtxt'
frozen_model = 'frozen_inference_graph.pb'

# %%
model = cv2.dnn_DetectionModel(frozen_model,config_file)

# %%
classLables = [] #empty list of python
file_name= 'labels.txt'
with open(file_name,'rt') as fpt:
    classLabels = fpt.read().rstrip('\n').split('\n')
 #classLables.append(fpt.read())

# %%
print(classLabels)
# Out:
# ['person', 'bicycle', 'car', 'motorbike', 'aeroplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'sofa', 'pottedplant', 'bed', 'diningtable', 'toilet', 'tvmonitor', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']
# ['person', 'bicycle', 'car', 'motorbike', 'aeroplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'sofa', 'pottedplant', 'bed', 'diningtable', 'toilet', 'tvmonitor', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']

# %%
print(len(classLabels))
# Out:
# 80
# 80

# %%
model.setInputSize(320,320)
model.setInputScale(1.0/127.5) ## 255/2=127.5
model.setInputMean((127.5,127.5,127.5)) ## mobilnet => [-1,1]
model.setInputSwapRB(True)
# Out:
# < cv2.dnn.Model 00000247DCEA46F0>
# < cv2.dnn.Model 00000247DCEA46F0>

# %%
img = cv2.imread('john-arano-LzxsSWAVMYs-unsplash.JPG')

# %%
image_inf = Image.open('john-arano-LzxsSWAVMYs-unsplash.JPG')

# %%
# extract other basic metadata
info_dict = {
 "Filename": image_inf.filename,
 "Image Size": image_inf.size,
 "Image Height": image_inf.height,
 "Image Width": image_inf.width,
 "Image Format": image_inf.format,
 "Image Mode": image_inf.mode,
 "Image is Animated": getattr(image_inf, "is_animated", False),
 "Frames in Image": getattr(image_inf, "n_frames", 1)
}
for label,value in info_dict.items():
    print(f"{label:25}: {value}")
# Out:
# Filename                 : photo.jpg
# Image Size               : (6000, 4000)
# Image Height             : 4000
# Image Width              : 6000
# Image Format             : JPEG
# Image Mode               : RGB
# Image is Animated        : False
# Frames in Image          : 1
# Filename                 : photo.jpg
# Image Size               : (6000, 4000)
# Image Height             : 4000
# Image Width              : 6000
# Image Format             : JPEG
# Image Mode               : RGB
# Image is Animated        : False
# Frames in Image          : 1

# %%
# extract EXIF data
exifdata = image_inf.getexif()

# %%
# looping through all the tags present in exifdata
for tagid in exifdata:
 
 # getting the tag name instead of tag id
    tagname = TAGS.get(tagid, tagid)
 # passing the tagid to get its respective value
    value = exifdata.get(tagid)
 
 # printing the final result
    print(f"{tagname:25}: {value}")

# %%
print(type(image_inf))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
image = skimage.img_as_float(img)
plt.imshow(image)

# %%
ClassIndex , confidece, bbox = model.detect(img, confThreshold=0.5)

# %%
print(ClassIndex)
# Out:
# [ 1  1  1 64  1 67 62 84 84 62 64  1  1  1  1 84 64]
# [ 1  1  1 64  1 67 62 84 84 62 64  1  1  1  1 84 64]

# %%
font_scale = 2
font = cv2.FONT_HERSHEY_PLAIN
for ClassInd, conf, boxes in zip(ClassIndex.flatten(), confidece.flatten(), bbox):
 #cv2.rectangle(frame, (x,y),(x+w , y+h),(255,0,0),2)
 #cv2.putText(img, text, (text_offset_x, text_offset_y), font, fontScale = fon
    cv2.rectangle(img, boxes,(255, 0, 0), 2)
    cv2.putText(img, classLabels[ClassInd-1], (boxes[0]+10, boxes[1]+40), font, fontScale=font_scale, color=(0, 255, 0), thickness=2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 7
#       3 for ClassInd, conf, boxes in zip(ClassIndex.flatten(), confidece.flatten(), bbox):
#       4  #cv2.rectangle(frame, (x,y),(x+w , y+h),(255,0,0),2)
#       5  #cv2.putText(img, text, (text_offset_x, text_offset_y), font, fontScale = fon
#       6     cv2.rectangle(img, boxes,(255, 0, 0), 2)
# ----> 7     cv2.putText(img, classLabels[ClassInd-1], (boxes[0]+10, boxes[1]+40), font, fontScale=font_scale, color=(0, 255, 0), thickness=2)
#
# IndexError: list index out of range
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 7
#       3 for ClassInd, conf, boxes in zip(ClassIndex.flatten(), confidece.flatten(), bbox):
#       4  #cv2.rectangle(frame, (x,y),(x+w , y+h),(255,0,0),2)
#       5  #cv2.putText(img, text, (text_offset_x, text_offset_y), font, fontScale = fon
#       6     cv2.rectangle(img, boxes,(255, 0, 0), 2)
# ----> 7     cv2.putText(img, classLabels[ClassInd-1], (boxes[0]+10, boxes[1]+40), font, fontScale=font_scale, color=(0, 255, 0), thickness=2)
#
# IndexError: list index out of range

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
cv2.imwrite("test.JPG",img)
